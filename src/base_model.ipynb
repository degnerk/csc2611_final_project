# %% [markdown]
# ## Base Model for Dog Breed Classification From Images
#
# #### The is the base model from which we will perform more hyperparameter testing and data augmentation for model improvements. In order to achieve the highest accuracy possible, this model is using transfer learning with the ImageNet data in order to start with a higher accuracy.

# %%
# Imports
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing import image as image_utils
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np
import glob, os

# %%
# Helper Functions
def get_image(image_path):
    image = mpimg.imread(image_path)
    return image

def load_and_scale_image(image_path):
    image = image_utils.load_img(image_path, target_size=(224,224))
    return image

def preprocess_image(image):
    image = image_utils.img_to_array(image)
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    image = preprocess_input(image)
    return image

# %%
# Directory Levels

print(os.listdir('../data/70-dog-breedsimage-data-set'))
print(os.listdir('../data/70-dog-breedsimage-data-set/test'))
# Out:
# ['dogs.csv', 'test', 'train', 'valid']
# ['Afghan', 'African Wild Dog', 'Airedale', 'American Hairless', 'American Spaniel', 'Basenji', 'Basset', 'Beagle', 'Bearded Collie', 'Bermaise', 'Bichon Frise', 'Blenheim', 'Bloodhound', 'Bluetick', 'Border Collie', 'Borzoi', 'Boston Terrier', 'Boxer', 'Bull Mastiff', 'Bull Terrier', 'Bulldog', 'Cairn', 'Chihuahua', 'Chinese Crested', 'Chow', 'Clumber', 'Cockapoo', 'Cocker', 'Collie', 'Corgi', 'Coyote', 'Dalmation', 'Dhole', 'Dingo', 'Doberman', 'Elk Hound', 'French Bulldog', 'German Sheperd', 'Golden Retriever', 'Great Dane', 'Great Perenees', 'Greyhound', 'Groenendael', 'Irish Spaniel', 'Irish Wolfhound', 'Japanese Spaniel', 'Komondor', 'Labradoodle', 'Labrador', 'Lhasa', 'Malinois', 'Maltese', 'Mex Hairless', 'Newfoundland', 'Pekinese', 'Pit Bull', 'Pomeranian', 'Poodle', 'Pug', 'Rhodesian', 'Rottweiler', 'Saint Bernard', 'Schnauzer', 'Scotch Terrier', 'Shar_Pei', 'Shiba Inu', 'Shih-Tzu', 'Siberian Husky', 'Vizsla', 'Yorkie']

# %%
# Sample Images

img1 = mpimg.imread('../data/70-dog-breedsimage-data-set/test/Boston Terrier/09.jpg')
img2 = mpimg.imread('../data/70-dog-breedsimage-data-set/test/Shiba Inu/04.jpg')
fig, axes = plt.subplots(1, 2, figsize=(6, 3))
axes[0].imshow(img1)
axes[1].imshow(img2)
plt.tight_layout()
plt.show()

# %%
for dog in glob.glob('../data/70-dog-breedsimage-data-set/test/*'):
    if os.path.isdir(dog):  # Ensure it's a directory
        for image in glob.glob(f'{dog}/*.jpg'):
            # Do something with each image
            print(image)
# Out:
# ../data/70-dog-breedsimage-data-set/test\Afghan\01.jpg
# ../data/70-dog-breedsimage-data-set/test\Afghan\02.jpg
# ../data/70-dog-breedsimage-data-set/test\Afghan\03.jpg
# ../data/70-dog-breedsimage-data-set/test\Afghan\04.jpg
# ../data/70-dog-breedsimage-data-set/test\Afghan\05.jpg
# ../data/70-dog-breedsimage-data-set/test\Afghan\06.jpg
# ../data/70-dog-breedsimage-data-set/test\Afghan\07.jpg
# ../data/70-dog-breedsimage-data-set/test\Afghan\08.jpg
# ../data/70-dog-breedsimage-data-set/test\Afghan\09.jpg
# ../data/70-dog-breedsimage-data-set/test\Afghan\10.jpg
# ../data/70-dog-breedsimage-data-set/test\African Wild Dog\01.jpg
# ../data/70-dog-breedsimage-data-set/test\African Wild Dog\02.jpg
# ../data/70-dog-breedsimage-data-set/test\African Wild Dog\03.jpg
# ../data/70-dog-breedsimage-data-set/test\African Wild Dog\04.jpg
# ../data/70-dog-breedsimage-data-set/test\African Wild Dog\05.jpg
# ../data/70-dog-breedsimage-data-set/test\African Wild Dog\06.jpg
# ...
